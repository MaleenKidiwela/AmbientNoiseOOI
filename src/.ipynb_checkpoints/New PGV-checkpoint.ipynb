# %%
import numpy as np
import matplotlib.pyplot as plt
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from concurrent.futures import ThreadPoolExecutor, as_completed

network = "OO"
station = "HYS14"
location = ""
channel = "BHZ"
client = Client("IRIS")

# Define a function to calculate peak ground velocity
def calculate_pgv(stream, inventory):
    try:
        # Detrend and taper the data
        stream.detrend("demean")
        stream.detrend("linear")
        stream.taper(max_percentage=0.05)
        
        # Remove the instrumental response to get velocity
        pre_filt = (0.005, 0.006, 80.0, 100.0)  # Bandpass filter parameters
        stream.remove_response(inventory=inventory, output='VEL', pre_filt=pre_filt, zero_mean=False, taper=False)
        
        # Calculate PGV (maximum absolute amplitude)
        pgv = np.max(np.abs(stream[0].data))
        
        return pgv
    except Exception as e:
        print(f"Failed to process data: {e}")
        return None

# %%
# Fetch the inventory once
inventory = client.get_stations(network=network, station=station, location=location,
                                channel=channel, level="response", starttime=UTCDateTime("2014-10-01"),
                                endtime=UTCDateTime("2020-12-31"))

# Define the start and end date for the data request
start_date = UTCDateTime("2014-10-01")
end_date = UTCDateTime("2020-12-31")

# Initialize an empty list to store results
pgv_results = []

def process_day(current_date):
    try:
        # Fetch the data for the current day
        st = client.get_waveforms(network=network, station=station, location=location,
                                  channel=channel, starttime=current_date,
                                  endtime=current_date + 86400)
        # Calculate PGV for the current day
        pgv = calculate_pgv(st, inventory)
        return (current_date.date, pgv)
    except Exception as e:
        print(f"Failed to process data for {current_date.date}: {e}")
        return (current_date.date, None)

# Use ThreadPoolExecutor to parallelize the process
with ThreadPoolExecutor(max_workers=10) as executor:
    futures = []
    current_date = start_date
    while current_date <= end_date:
        futures.append(executor.submit(process_day, current_date))
        current_date += 86400

    for future in as_completed(futures):
        result = future.result()
        if result[1] is not None:
            pgv_results.append(result)
            print(f"PGV for {result[0]}: {result[1]:.4f}")

# Save results to a CSV file
output_file = "pgv_results.csv"
with open(output_file, 'w') as f:
    f.write("Date,PGV\n")
    for date, pgv in pgv_results:
        f.write(f"{date},{pgv:.4f}\n")

print(f"Results saved to {output_file}")
# Out:
# Failed to process data for 2014-10-01: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-08: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-02: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-04: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-06: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-07: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-05: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-03: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-09: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-11: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-10: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-13: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-14: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-12: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-18: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-17: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-16: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-15: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-22: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-19: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-23: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-20: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-21: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-25: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-26: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-29: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-24: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-27: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-28: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-03: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-30: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-10-31: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-01: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-02: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-09: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-05: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-07: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-06: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-08: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-11: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-04: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-10: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-12: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-13: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-14: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-18: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-19: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-15: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-16: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-20: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-17: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-24: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-21: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-22: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-23: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-27: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-26: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-29: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-25: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-01: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-28: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-11-30: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-02: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-06: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-07: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-04: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-08: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-03: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-05: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-10: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
# Failed to process data for 2014-12-09: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-13: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-12: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-18: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-11: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-19: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-17: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-14: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-16: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-15: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-20: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-23: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-24: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-25: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-22: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-27: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-21: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-28: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-29: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-30: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-26: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-02: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-01: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2014-12-31: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-05: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-06: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-03: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-08: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-04: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-07: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-10: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-11: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-13: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-14: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-09: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-12: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-18: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-15: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-17: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-20: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-16: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-22: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-23: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-19: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-21: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-25: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-24: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-27: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-30: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-26: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-31: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-29: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-01-28: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-02: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-03: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-01: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-04: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-10: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-11: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-06: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-05: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-12: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-07: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-09: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-08: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-13: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-18: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-14: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-15: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-22: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-19: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-20: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-17: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-16: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-21: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
# Failed to process data for 2015-02-23: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-24: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-25: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-26: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-27: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-03-01: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-03-03: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-02-28: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-03-02: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Failed to process data for 2015-03-07: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# PGV for 2015-03-04: 0.0000
# PGV for 2015-03-06: 0.0000
# PGV for 2015-03-08: 0.0000
# PGV for 2015-03-05: 0.0000
# PGV for 2015-03-09: 0.0000
# PGV for 2015-03-10: 0.0000
# PGV for 2015-03-13: 0.0000
# PGV for 2015-03-11: 0.0000
# PGV for 2015-03-14: 0.0000
# PGV for 2015-03-12: 0.0000
# PGV for 2015-03-15: 0.0002
# PGV for 2015-03-16: 0.0001
# PGV for 2015-03-18: 0.0000
# PGV for 2015-03-19: 0.0000
# PGV for 2015-03-17: 0.0000
# PGV for 2015-03-20: 0.0000
# PGV for 2015-03-24: 0.0001
# PGV for 2015-03-25: 0.0000
# PGV for 2015-03-23: 0.0000
# PGV for 2015-03-22: 0.0000
# PGV for 2015-03-21: 0.0000
# PGV for 2015-03-26: 0.0000
No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# PGV for 2020-08-15: 0.0000
# PGV for 2020-08-16: 0.0000
# PGV for 2020-08-17: 0.0000
# Results saved to pgv_results.csv

# %%
def process_day(current_date):
    try:
        # Fetch the data for the current day
        st = client.get_waveforms(network=network, station=station, location=location,
                                  channel=channel, starttime=current_date,
                                  endtime=current_date + 86400)
        # Calculate PGV for the current day
        pgv = calculate_pgv(st, inventory)
        return (current_date.date, pgv)
    except Exception as e:
        print(f"Failed to process data for {current_date.date}: {e}")
        return (current_date.date, None)

# %%
# Use ThreadPoolExecutor to parallelize the process
with ThreadPoolExecutor(max_workers=10) as executor:
    futures = []
    current_date = start_date
    while current_date <= end_date:
        futures.append(executor.submit(process_day, current_date))
        current_date += 86400

    for future in as_completed(futures):
        result = future.result()
        if result[1] is not None:
            pgv_results.append(result)
            print(f"PGV for {result[0]}: {result[1]:.4f}")

# %%
# Sort results by date
pgv_results.sort(key=lambda x: x[0])

# Save results to a CSV file
output_file = "pgv_results_newnew.csv"
with open(output_file, 'w') as f:
    f.write("Date,PGV\n")
    for date, pgv in pgv_results:
        f.write(f"{date},{pgv:.4f}\n")

print(f"Results saved to {output_file}")

# %%
pgv_results.sort(key=lambda x: x[0])

# %%
# Plot PGV as a function of time
dates, pgvs = zip(*pgv_results)
plt.figure(figsize=(14, 4),dpi=200)
plt.plot(dates, pgvs, marker='o', linestyle='-', markersize=4)
plt.xlabel('Date')
plt.ylabel('Peak Ground Velocity (m/s)')
plt.title('Peak Ground Velocity over Time')
plt.grid(True)
plt.tight_layout()
plt.savefig('pgv_plot.png')
plt.show()

# %%
pgv_results

# %%
# %matplotlib ipympl

import obspy
import numpy as np
import matplotlib.pyplot as plt
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from concurrent.futures import ThreadPoolExecutor, as_completed



t1 = obspy.UTCDateTime("2016-07-18T21:00:00.000")
t2 = obspy.UTCDateTime("2016-07-18T21:10:00.000")

fig, ax = plt.subplots(2,figsize=(10,5))
st1 = client.get_waveforms("OO", "HYSB1", "*", "BHZ", t1-5, t2+5,attach_response=True);
st1.resample(200).merge(fill_value='interpolate')
st1.remove_response()
# st1.filter('bandpass',freqmin=4,freqmax=15)
st1.trim(starttime=t1,endtime=t2)
ax[0].plot(st1[0].data,'k',linewidth=0.5)
ax[0].set_xlim(0,len(st1[0].data))
ax[0].set_title('Vertical seismogram, unfiltered 4-15 Hz')
ax[0].set_xticks([])
ax[0].set_ylabel('Velocity (m/s)')
# Spectrogram- unfiltered
st2 = client.get_waveforms("OO", "HYSB1", "*", "HHZ", t1-5, t2+5);
st2.resample(200).merge(fill_value='interpolate')
st2.trim(starttime=t1,endtime=t2)
st2[0].spectrogram(axes=ax[1])
mappable = ax[1].images[0]
#plt.colorbar(mappable=mappable)
ax[1].images[0].set_clim(0,50)
ax[1].set_ylim([0,100])
ax[1].set_title('Spectrogram, unfiltered')
ax[1].set_ylabel('Frequency (Hz)')
ax[1].set_xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
client = Client('IRIS')
t1 = obspy.UTCDateTime("2016-07-15T00:00:00.000")
t2 = obspy.UTCDateTime("2016-07-19T12:00:00.000")
st2 = client.get_waveforms("OO", "HYSB1", "*", "HHZ", t1, t2);
st2.resample(200).merge(fill_value='interpolate')
st2.filter('bandpass',freqmin=4,freqmax=15).plot(type='dayplot');
